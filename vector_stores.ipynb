# %%
# import sys
# !{sys.executable} -m pip install langchain chromadb openai tiktoken pypdf langchain_openai langchain-community

# %%
# import sys
# !{sys.executable} -m pip install -U langchain-chroma

# %%
from langchain_ollama import ChatOllama, OllamaEmbeddings
from langchain_chroma import Chroma

# %%
from langchain_core.documents import Document

# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
vector_store = Chroma(
    embedding_function=OllamaEmbeddings(model="nomic-embed-text"),  # Specify that where we store this embediing into DB , which model is used to convert into vectors  
    persist_directory='chroma_db_new',  # Where we store our data
    collection_name='sample'
)

# %%
# Add documents
vector_store.add_documents(docs)  # We can add number of document here 
# It not only store but it can provide unique id also.
# Out:
# ['6a32f2eb-3619-48ae-a9a5-ec2b308c8f41',
#  'fe8631c1-878a-4549-a7cd-81a601149a86',
#  'bd3d88a4-aac6-46fb-af79-ad2d42b80adf',
#  '56bff05e-284c-499c-b309-ec72a356ff9a',
#  'a683c79a-a822-4f18-a871-9c917ba0af4b']

# %%
# View Documents
vector_store.get(include=['embeddings','documents','metadatas'])
# Out:
# {'ids': ['0571b0bd-ec3b-4da7-b737-9714096bb1be',
#   '0f07753f-b2be-43d2-9e9d-ad73d9ecbec3',
#   '08188d4b-2ea2-4f04-ab08-04d1a47277c8',
#   '54650a2a-c60d-4c1e-9d8a-f3da5e67b360',
#   '7d9e6c10-ab94-4005-ae8c-95df19074f43',
#   '6a32f2eb-3619-48ae-a9a5-ec2b308c8f41',
#   'fe8631c1-878a-4549-a7cd-81a601149a86',
#   'bd3d88a4-aac6-46fb-af79-ad2d42b80adf',
#   '56bff05e-284c-499c-b309-ec72a356ff9a',
#   'a683c79a-a822-4f18-a871-9c917ba0af4b'],
#  'embeddings': array([[-0.02396619,  0.04441593, -0.18950675, ..., -0.01615584,
#          -0.05862798,  0.00257752],
#         [-0.03155498,  0.07576069, -0.16425164, ..., -0.06556196,
#          -0.02184978, -0.01400085],
#         [ 0.02292822,  0.06587882, -0.1838091 , ..., -0.0213266 ,
#          -0.04228141,  0.00050898],
#         ...,
#         [ 0.02292822,  0.06587882, -0.1838091 , ..., -0.0213266 ,
#          -0.04228141,  0.00050898],
#         [ 0.01441059,  0.03139739, -0.18330717, ..., -0.02946112,
# ...

# %%
# Search documents
vector_store.similarity_search(
    query='Who among this are bowler?',
    k=2  # how many similer object you want 
)
# Out:
# [Document(id='54650a2a-c60d-4c1e-9d8a-f3da5e67b360', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(id='56bff05e-284c-499c-b309-ec72a356ff9a', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.')]

# %%
# search with similer score
vector_store.similarity_search_with_score(
    query='Who among this are bowler?',
    k=2
)

# Score less means its good
# Out:
# [(Document(id='54650a2a-c60d-4c1e-9d8a-f3da5e67b360', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.6742910742759705),
#  (Document(id='56bff05e-284c-499c-b309-ec72a356ff9a', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.6742910742759705)]

# %%
# metadata filtering
vector_store.similarity_search_with_score(
    query=" ",
    filter={"team": "Mumbai Indians"}
)
# Out:
# [(Document(id='54650a2a-c60d-4c1e-9d8a-f3da5e67b360', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.8478939533233643),
#  (Document(id='56bff05e-284c-499c-b309-ec72a356ff9a', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.8478939533233643),
#  (Document(id='0f07753f-b2be-43d2-9e9d-ad73d9ecbec3', metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#   0.873024582862854),
# ...

# %%
# update Documents
updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)

vector_store.update_document(document_id='6a32f2eb-3619-48ae-a9a5-ec2b308c8f41', document=updated_doc1)  # We provide document id to update it.

# %%
# delete document
vector_store.delete(ids=[''])

# %%
# view Document
vector_store.get(include=['embeddings','documents', 'metadatas'])
